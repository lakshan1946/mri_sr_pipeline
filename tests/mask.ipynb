# %%
import ants

# %%
mni_template = ants.image_read('../data/templates/mni152_template.nii.gz')

# %%
mni_mask = ants.get_mask(mni_template)

# %%
# Save mni mask
ants.image_write(mni_mask, "../data/templates/mni152_mask.nii.gz")
